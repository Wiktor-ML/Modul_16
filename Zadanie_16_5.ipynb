# %% [markdown]
# # Tutorial

# %%
import pandas as pd
diabetes = pd.read_csv('diabetes.csv')
diabetes
# Out:
#        PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0        1354778            0            171                      80
# 1        1147438            8             92                      93
# 2        1640031            7            115                      47
# 3        1883350            9            103                      78
# 4        1424119            1             85                      59
# ...          ...          ...            ...                     ...
# 14995    1490300           10             65                      60
# 14996    1744410            2             73                      66
# 14997    1742742            0             93                      89
# 14998    1099353            0            132                      98
# 14999    1386396            3            114                      65
#
#        TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# ...

# %%
features = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']
target = 'Diabetic'
X, y = diabetes[features], diabetes[target]
print('X:')
display(X)
print('\ny:')
display(y)
# Out:
# X:
#        Pregnancies  PlasmaGlucose  DiastolicBloodPressure  TricepsThickness  \
# 0                0            171                      80                34
# 1                8             92                      93                47
# 2                7            115                      47                52
# 3                9            103                      78                25
# 4                1             85                      59                27
# ...            ...            ...                     ...               ...
# 14995           10             65                      60                46
# 14996            2             73                      66                27
# 14997            0             93                      89                43
# 14998            0            132                      98                18
# 14999            3            114                      65                47
#
# ...

# %%
pd.Series(y).value_counts(normalize=True)
# Out:
# Diabetic
# 0    0.666667
# 1    0.333333
# Name: proportion, dtype: float64

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PatientID               15000 non-null  int64
#  1   Pregnancies             15000 non-null  int64
#  2   PlasmaGlucose           15000 non-null  int64
#  3   DiastolicBloodPressure  15000 non-null  int64
#  4   TricepsThickness        15000 non-null  int64
#  5   SerumInsulin            15000 non-null  int64
#  6   BMI                     15000 non-null  float64
#  7   DiabetesPedigree        15000 non-null  float64
#  8   Age                     15000 non-null  int64
#  9   Diabetic                15000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.1 MB

# %%
X.describe()
# Out:
#         Pregnancies  PlasmaGlucose  DiastolicBloodPressure  TricepsThickness  \
# count  15000.000000   15000.000000            15000.000000      15000.000000
# mean       3.224533     107.856867               71.220667         28.814000
# std        3.391020      31.981975               16.758716         14.555716
# min        0.000000      44.000000               24.000000          7.000000
# 25%        0.000000      84.000000               58.000000         15.000000
# 50%        2.000000     104.000000               72.000000         31.000000
# 75%        6.000000     129.000000               85.000000         41.000000
# max       14.000000     192.000000              117.000000         93.000000
#
#        SerumInsulin           BMI  DiabetesPedigree           Age
# count  15000.000000  15000.000000      15000.000000  15000.000000
# mean     137.852133     31.509646          0.398968     30.137733
# std      133.068252      9.759000          0.377944     12.089703
# ...

# %%
import matplotlib.pyplot as plt
for col in features:
    print(f'Unique values: {len(diabetes[col].unique())}')
    diabetes.boxplot(column=col, by='Diabetic', figsize=(6,5))
    plt.title(col)
    plt.show()
# Out:
# Unique values: 15
# Unique values: 149
# Unique values: 90
# Unique values: 69
# Unique values: 663
# Unique values: 15000
# Unique values: 14999
# Unique values: 56

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
import seaborn as sns
for col in features:
    plt.figure(figsize=(12, 2.5))
    sns.distplot(diabetes.loc[diabetes['Diabetic']==0, col], kde=True, color='green', label='Osoba zdrowa')
    sns.distplot(diabetes.loc[diabetes['Diabetic']==1, col], kde=True, color='red', label='Cukrzyk')
    plt.legend(loc='upper right')
    plt.show()

# %%
plt.figure(figsize=(8, 8))
ax = sns.heatmap(X.corr(),
                 xticklabels=X.corr().columns,
                 yticklabels=X.corr().columns,
                 cmap='RdYlGn',
                 center=0,
                 annot=True)

plt.title('Korelacja dla zmiennych numerycznych', fontsize=22)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
from scipy import stats

corr_dict = {}
for col in features:
    corr_dict[col] = stats.pointbiserialr(X[col], y)[0]
pd.Series(corr_dict).sort_values(ascending=False)
# Out:
# Pregnancies               0.407315
# Age                       0.342605
# SerumInsulin              0.247375
# BMI                       0.210508
# DiabetesPedigree          0.170302
# TricepsThickness          0.152505
# PlasmaGlucose             0.128004
# DiastolicBloodPressure    0.091307
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X[['Pregnancies', 'Age']], y, test_size=0.30, random_state=0, stratify=y)
print ('Treningowe obserwacje: %d\nTestowe obserwacje: %d' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Treningowe obserwacje: 10500
# Testowe obserwacje: 4500

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

scaler_2var = StandardScaler()
X_train_standardized = scaler_2var.fit_transform(X_train)
X_test_standardized = scaler_2var.transform(X_test)
model_lr = LogisticRegression()
model_lr.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression()

# %%
from numpy import where
from numpy import meshgrid
from numpy import arange
from numpy import hstack

def plot_classification_surface(X_plot, y_plot, trained_model):
    plt.figure(figsize=(12, 7))

    # określenie granic zbioru
    min1, max1 = X_plot[:, 0].min()-1, X_plot[:, 0].max()+1
    min2, max2 = X_plot[:, 1].min()-1, X_plot[:, 1].max()+1

    # skalowanie dla obu osi
    x1grid = arange(min1, max1, 0.1)
    x2grid = arange(min2, max2, 0.1)

    # utworzenie siatki
    xx, yy = meshgrid(x1grid, x2grid)

    # przetworzenie siatki w wektor
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((len(r1), 1)), r2.reshape((len(r2), 1))

    # stworzenie zmiennych objaśniających dla modelu
    grid = hstack((r1,r2))

    # predykcja modelu zbioru
    yhat = trained_model.predict(grid)

    # przetworzenie predykcji na decyzji dla konkretnego punktu wykresu
    zz = yhat.reshape(xx.shape)

    # wizualizacja siatki z przyporządkowaną klasą
    plt.contourf(xx, yy, zz, cmap='Paired')

    # tworzenie wykresu punktowego dla klas ze zbioru X
    for class_value in range(2):

        # przyporządkowanie klasy (y) do obsewacji (X)
        row_ix = where(y_plot == class_value)

        # stworzenie wykresu punktowego
        plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

    # wizualizacja wykresu
    plt.legend(loc='upper right')
    plt.show()

plot_classification_surface(X_plot=X_train_standardized, y_plot=y_train, trained_model=model_lr)

# %%
predictions_lr = model_lr.predict(X_test_standardized)
print('Predicted labels: ', predictions_lr[:5], predictions_lr[-5:])
print('Actual labels:    ' , y_test[:5].values, y_test[-5:].values)
# Out:
# Predicted labels:  [0 0 1 0 0] [1 0 1 0 0]
# Actual labels:     [0 1 0 0 0] [1 1 0 0 0]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, predictions_lr)
ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='.0f')
ax.set_title('Confusion Matrix\n\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy: ', accuracy_score(y_test, predictions_lr))
print("Precision:", precision_score(y_test, predictions_lr))
print("Recall:", recall_score(y_test, predictions_lr))
print("F1_score:", f1_score(y_test, predictions_lr))
# Out:
# Accuracy:  0.7451111111111111
# Precision: 0.6426839126919968
# Recall: 0.53
# F1_score: 0.5809280233832663

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82      3000
#            1       0.64      0.53      0.58      1500
#
#     accuracy                           0.75      4500
#    macro avg       0.71      0.69      0.70      4500
# weighted avg       0.74      0.75      0.74      4500

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# prognoza prawdopodobieństwa
predictions_probability_lr = model_lr.predict_proba(X_test_standardized)

# obliczenie FPR oraz TPR w zależności od punktu odcięcia
fpr, tpr, thresholds = roc_curve(y_test, predictions_probability_lr[:,1])

# wizualizacja ROC Curve
fig = plt.figure(figsize=(6, 6))

# rysowanie prostej dla modelu losowego
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# obliczenie AUC
auc = roc_auc_score(y_test, predictions_probability_lr[:,1])
print('AUC: ' + str(auc))
# Out:
# AUC: 0.8164931111111111

# %%
metrics_dataframe = pd.DataFrame(columns = ['Model', 'F1_score', 'AUC'])
metrics_dataframe
models = []
models_names = []
predictions_proba_list = []
def calculate_metrics(model, name, X_checked, y_checked):
    models.append(model)
    models_names.append(name)
    global metrics_dataframe
    predictions = model.predict(X_checked)
    predictions_proba = model.predict_proba(X_checked)
    predictions_proba_list.append(predictions_proba[:,1])

    ############## metryki dla sprawdzanego modelu ################
    # Precision, Recall, F1, Accuracy
    print(classification_report(y_checked, predictions))

    # Confusion matrix
    plt.figure()
    cm = confusion_matrix(y_checked, predictions)
    ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='.0f')
    ax.set_title('Confusion Matrix\n\n')
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ')
    plt.show()

    # plot ROC curve
    fig = plt.figure(figsize=(6, 6))
    plt.plot([0, 1], [0, 1], 'k--')
    for model_selected, name_selected, pred_proba in zip(models, models_names, predictions_proba_list):
        fpr, tpr, thresholds = roc_curve(y_checked, pred_proba)
        plt.plot(fpr, tpr, label=name_selected)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

    f1_metric = f1_score(y_checked, predictions)
    auc_metric = roc_auc_score(y_checked, predictions_proba[:,1])
    metrics_dataframe = pd.concat([
    metrics_dataframe,
    pd.DataFrame([{
        'Model': name,
        'F1_score': f1_metric,
        'AUC': auc_metric
    }])
], ignore_index=True)
    return metrics_dataframe

# %%
calculate_metrics(model_lr, 'Logistic Regression', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82      3000
#            1       0.64      0.53      0.58      1500
#
#     accuracy                           0.75      4500
#    macro avg       0.71      0.69      0.70      4500
# weighted avg       0.74      0.75      0.74      4500
# C:\Users\wikto\AppData\Local\Temp\ipykernel_82608\3219724939.py:41: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_dataframe = pd.concat([
#                  Model  F1_score       AUC
# 0  Logistic Regression  0.580928  0.816493

# %% [markdown]
# # Trenownie modeli

# %% [markdown]
# ## Wynik z regularyzacja L1

# %%
model_lr_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1, random_state=42)

# %%
model_lr_l1.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, penalty='l1', random_state=42, solver='liblinear')

# %%
calculate_metrics(model_lr_l1, 'Logistic Regression L1', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82      3000
#            1       0.64      0.53      0.58      1500
#
#     accuracy                           0.75      4500
#    macro avg       0.71      0.69      0.70      4500
# weighted avg       0.74      0.75      0.74      4500
#                     Model  F1_score       AUC
# 0     Logistic Regression  0.580928  0.816493
# 1  Logistic Regression L1  0.580928  0.816493

# %% [markdown]
# ## Wynik z regularyzacja L2

# %%
model_lr_l2 = LogisticRegression(penalty='l2', solver='lbfgs', C=1, random_state=42)

# %%
model_lr_l2.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, random_state=42)

# %%
calculate_metrics(model_lr_l2, 'Logistic Regression L2', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82      3000
#            1       0.64      0.53      0.58      1500
#
#     accuracy                           0.75      4500
#    macro avg       0.71      0.69      0.70      4500
# weighted avg       0.74      0.75      0.74      4500
#                     Model  F1_score       AUC
# 0     Logistic Regression  0.580928  0.816493
# 1  Logistic Regression L1  0.580928  0.816493
# 2  Logistic Regression L2  0.580928  0.816493

# %% [markdown]
# ## Wynik z regularyzacja Elastic Net

# %%
model_lr_l1_l2 = LogisticRegression(penalty='elasticnet', solver='saga', C=1, l1_ratio=0.1, random_state=42)

# %%
model_lr_l1_l2.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, l1_ratio=0.1, penalty='elasticnet', random_state=42,
#                    solver='saga')

# %%
calculate_metrics(model_lr_l1_l2, 'Logistic Regression ElasticNet', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82      3000
#            1       0.64      0.53      0.58      1500
#
#     accuracy                           0.75      4500
#    macro avg       0.71      0.69      0.70      4500
# weighted avg       0.74      0.75      0.74      4500
#                             Model  F1_score       AUC
# 0             Logistic Regression  0.580928  0.816493
# 1          Logistic Regression L1  0.580928  0.816493
# 2          Logistic Regression L2  0.580928  0.816493
# 3  Logistic Regression ElasticNet  0.580928  0.816493

# %% [markdown]
# ## GridSearchCV for the model parameter

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for C
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}

# For L2 regularization
grid_l2 = GridSearchCV(
    LogisticRegression(penalty='l2', solver='lbfgs', random_state=42),
    param_grid,
    cv=5,
    scoring='f1'
)
grid_l2.fit(X_train_standardized, y_train)
best_C_l2 = grid_l2.best_params_['C']
print(f"Best C for L2: {best_C_l2}")

# Repeat for L1 (use solver='liblinear')
# Repeat for ElasticNet (use solver='saga', and also tune l1_ratio, see below)
# Out:
# Best C for L2: 1

# %%
param_grid_elastic = {
    'C': [0.01, 0.1, 1, 10, 100],
    'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]
}
grid_elastic = GridSearchCV(
    LogisticRegression(penalty='elasticnet', solver='saga', random_state=42),
    param_grid_elastic,
    cv=5,
    scoring='f1'
)
grid_elastic.fit(X_train_standardized, y_train)
best_C_elastic = grid_elastic.best_params_['C']
best_l1_ratio = grid_elastic.best_params_['l1_ratio']
print(f"Best C for ElasticNet: {best_C_elastic}")
print(f"Best l1_ratio for ElasticNet: {best_l1_ratio}")
# Out:
# Best C for ElasticNet: 1
# Best l1_ratio for ElasticNet: 0.1

# %%
# For L1 regularization
grid_l1 = GridSearchCV(
    LogisticRegression(penalty='l1', solver='saga', random_state=42),
    param_grid,
    cv=5,
    scoring='f1'
)
grid_l1.fit(X_train_standardized, y_train)
best_C_l1 = grid_l1.best_params_['C']
print(f"Best C for L1: {best_C_l1}")
# Out:
# Best C for L1: 1

# %% [markdown]
# ## Wynik z random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)

# Fit the model on the training data
rf_model.fit(X_train_standardized, y_train)

# Make predictions
y_pred_rf = rf_model.predict(X_test_standardized)
y_pred_proba_rf = rf_model.predict_proba(X_test_standardized)[:, 1]  # For AUC

# Evaluate performance
f1_rf = f1_score(y_test, y_pred_rf)
auc_rf = roc_auc_score(y_test, y_pred_proba_rf)

print(f"Random Forest F1 Score: {f1_rf}")
print(f"Random Forest AUC: {auc_rf}")
# Out:
# Random Forest F1 Score: 0.8249750913317835
# Random Forest AUC: 0.9513956666666665

# %%
calculate_metrics(rf_model, 'Random forest', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      3000
#            1       0.82      0.83      0.82      1500
#
#     accuracy                           0.88      4500
#    macro avg       0.87      0.87      0.87      4500
# weighted avg       0.88      0.88      0.88      4500
#                             Model  F1_score       AUC
# 0             Logistic Regression  0.580928  0.816493
# 1          Logistic Regression L1  0.580928  0.816493
# 2          Logistic Regression L2  0.580928  0.816493
# 3  Logistic Regression ElasticNet  0.580928  0.816493
# 4                   Random forest  0.824975  0.951396

# %% [markdown]
# ## Wyniki dla poly_deg=3 i logistic regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4)
X_train_poly = poly.fit_transform(X_train_standardized)
X_test_poly = poly.transform(X_test_standardized)

# %%
# Retrain logistic regression (e.g., L2 regularization) on polynomial features
model_lr_l2_3deg = LogisticRegression(penalty='l2', solver='lbfgs', C=0.01, random_state=42)
model_lr_l2_3deg.fit(X_train_poly, y_train)
# Out:
# LogisticRegression(C=0.01, random_state=42)

# %%
# Make predictions
y_pred_l2_3deg = model_lr_l2_3deg.predict(X_test_poly)
y_pred_proba_l2_3deg = model_lr_l2_3deg .predict_proba(X_test_poly)[:, 1]  # For AUC

# %%
calculate_metrics(model_lr_l2_3deg, 'l2_poly_3_deg', X_test_poly, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3000
#            1       0.84      0.64      0.73      1500
#
#     accuracy                           0.84      4500
#    macro avg       0.84      0.79      0.81      4500
# weighted avg       0.84      0.84      0.83      4500
#                             Model  F1_score       AUC
# 0             Logistic Regression  0.580928  0.816493
# 1          Logistic Regression L1  0.580928  0.816493
# 2          Logistic Regression L2  0.580928  0.816493
# 3  Logistic Regression ElasticNet  0.580928  0.816493
# 4                   Random forest  0.824975  0.951396
# 5                   l2_poly_3_deg  0.728782  0.913270

# %% [markdown]
# ## Podsumowanie plot_classification_surface

# %% [markdown]
# ### Regularyzacja L1

# %%
plot_classification_surface(X_test_standardized, y_test, model_lr_l1)

# %% [markdown]
# ### Regularyzacja L2

# %%
plot_classification_surface(X_test_standardized, y_test, model_lr_l2)

# %% [markdown]
# ### Regularyzacja Elastic Net (l1+l2)

# %%
plot_classification_surface(X_test_standardized, y_test, model_lr_l1_l2)

# %% [markdown]
# ### Random forest

# %%
plot_classification_surface(X_test_standardized, y_test, rf_model)

# %% [markdown]
# ## F1 Score na zbiorach treningowych i testowych wazona

# %%
# Define the models and their names
models_list = {
    'Logistic Regression L1': model_lr_l1,
    'Logistic Regression L2': model_lr_l2,
    'Logistic Regression ElasticNet': model_lr_l1_l2,  # Assuming model_lr_l1_l2 is ElasticNet
    'Random Forest': rf_model,
    'Logistic Regression Poly Deg 3': model_lr_l2_3deg
}

# Store F1 scores in a dictionary
f1_scores = {}

# Calculate and store F1 scores for each model
for model_name, model in models_list.items():
    # Handle different feature sets based on the model
    if model_name == 'Logistic Regression Poly Deg 3':
        # Use polynomial features for degree 3 model
        f1_train = f1_score(y_train, model.predict(X_train_poly), average='weighted')
        f1_test = f1_score(y_test, model.predict(X_test_poly), average='weighted')
    else:
        # Use standardized features for other models
        f1_train = f1_score(y_train, model.predict(X_train_standardized), average='weighted')
        f1_test = f1_score(y_test, model.predict(X_test_standardized), average='weighted')
    
    # Store the scores
    f1_scores[model_name] = {'F1_Train': f1_train, 'F1_Test': f1_test}

# Print the results in a formatted way
print("F1 Scores for Training and Test Sets wazona:")
print("-" * 50)
for model_name, scores in f1_scores.items():
    print(f"{model_name}:")
    print(f"  F1 Score (Train): {scores['F1_Train']:.4f}")
    print(f"  F1 Score (Test): {scores['F1_Test']:.4f}")
    print("-" * 50)
# Out:
# F1 Scores for Training and Test Sets wazona:
# --------------------------------------------------
# Logistic Regression L1:
#   F1 Score (Train): 0.7243
#   F1 Score (Test): 0.7382
# --------------------------------------------------
# Logistic Regression L2:
#   F1 Score (Train): 0.7243
#   F1 Score (Test): 0.7382
# --------------------------------------------------
# Logistic Regression ElasticNet:
#   F1 Score (Train): 0.7243
#   F1 Score (Test): 0.7382
# --------------------------------------------------
# Random Forest:
#   F1 Score (Train): 0.8982
#   F1 Score (Test): 0.8830
# --------------------------------------------------
# Logistic Regression Poly Deg 3:
#   F1 Score (Train): 0.8337
#   F1 Score (Test): 0.8341
# --------------------------------------------------

# %% [markdown]
# ## F1 Score na zbiorach treningowych i testowych class = 1

# %%
# Store F1 scores in a dictionary
f1_scores = {}

# Calculate and store F1 scores for each model
for model_name, model in models_list.items():
    # Handle different feature sets based on the model
    if model_name == 'Logistic Regression Poly Deg 3':
        # Use polynomial features for degree 3 model
        f1_train = f1_score(y_train, model.predict(X_train_poly))
        f1_test = f1_score(y_test, model.predict(X_test_poly))
    else:
        # Use standardized features for other models
        f1_train = f1_score(y_train, model.predict(X_train_standardized))
        f1_test = f1_score(y_test, model.predict(X_test_standardized))
    
    # Store the scores
    f1_scores[model_name] = {'F1_Train': f1_train, 'F1_Test': f1_test}

# Print the results in a formatted way
print("F1 Scores for Training and Test Sets Class 1:")
print("-" * 50)
for model_name, scores in f1_scores.items():
    print(f"{model_name}:")
    print(f"  F1 Score (Train): {scores['F1_Train']:.4f}")
    print(f"  F1 Score (Test): {scores['F1_Test']:.4f}")
    print("-" * 50)
# Out:
# F1 Scores for Training and Test Sets Class 1:
# --------------------------------------------------
# Logistic Regression L1:
#   F1 Score (Train): 0.5469
#   F1 Score (Test): 0.5809
# --------------------------------------------------
# Logistic Regression L2:
#   F1 Score (Train): 0.5469
#   F1 Score (Test): 0.5809
# --------------------------------------------------
# Logistic Regression ElasticNet:
#   F1 Score (Train): 0.5469
#   F1 Score (Test): 0.5809
# --------------------------------------------------
# Random Forest:
#   F1 Score (Train): 0.8472
#   F1 Score (Test): 0.8250
# --------------------------------------------------
# Logistic Regression Poly Deg 3:
#   F1 Score (Train): 0.7261
#   F1 Score (Test): 0.7288
# --------------------------------------------------

# %% [markdown]
# # Trening na wielkszej ilosci features

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify=y)
print ('Treningowe obserwacje: %d\nTestowe obserwacje: %d' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Treningowe obserwacje: 10500
# Testowe obserwacje: 4500

# %%
scaler_2var = StandardScaler()
X_train_standardized = scaler_2var.fit_transform(X_train)
X_test_standardized = scaler_2var.transform(X_test)
model_lr = LogisticRegression()
model_lr.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression()

# %%
model_lr_l1.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, penalty='l1', random_state=42, solver='liblinear')

# %%
calculate_metrics(model_lr_l1, 'Logistic Regression L1 wielksza ilosc features ', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      3000
#            1       0.72      0.62      0.66      1500
#
#     accuracy                           0.79      4500
#    macro avg       0.77      0.75      0.76      4500
# weighted avg       0.79      0.79      0.79      4500
#                                              Model  F1_score       AUC
# 0                              Logistic Regression  0.580928  0.816493
# 1                           Logistic Regression L1  0.580928  0.816493
# 2                           Logistic Regression L2  0.580928  0.816493
# 3                   Logistic Regression ElasticNet  0.580928  0.816493
# 4                                    Random forest  0.824975  0.951396
# 5                                    l2_poly_3_deg  0.728782  0.913270
# 6  Logistic Regression L1 wielksza ilosc features   0.664761  0.858629

# %%
model_lr_l2.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, random_state=42)

# %%
calculate_metrics(model_lr_l2, 'Logistic Regression L2 wieksza ilosc features', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      3000
#            1       0.72      0.62      0.66      1500
#
#     accuracy                           0.79      4500
#    macro avg       0.77      0.75      0.76      4500
# weighted avg       0.79      0.79      0.79      4500
#                                              Model  F1_score       AUC
# 0                              Logistic Regression  0.580928  0.816493
# 1                           Logistic Regression L1  0.580928  0.816493
# 2                           Logistic Regression L2  0.580928  0.816493
# 3                   Logistic Regression ElasticNet  0.580928  0.816493
# 4                                    Random forest  0.824975  0.951396
# 5                                    l2_poly_3_deg  0.728782  0.913270
# 6  Logistic Regression L1 wielksza ilosc features   0.664761  0.858629
# 7    Logistic Regression L2 wieksza ilosc features  0.664283  0.858624

# %%
model_lr_l1_l2.fit(X_train_standardized, y_train)
# Out:
# LogisticRegression(C=1, l1_ratio=0.1, penalty='elasticnet', random_state=42,
#                    solver='saga')

# %%
calculate_metrics(model_lr_l1_l2, 'Logistic Regression Elastic Net wieksza ilosc features', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      3000
#            1       0.72      0.62      0.66      1500
#
#     accuracy                           0.79      4500
#    macro avg       0.77      0.75      0.76      4500
# weighted avg       0.79      0.79      0.79      4500
#                                                Model  F1_score       AUC
# 0                                Logistic Regression  0.580928  0.816493
# 1                             Logistic Regression L1  0.580928  0.816493
# 2                             Logistic Regression L2  0.580928  0.816493
# 3                     Logistic Regression ElasticNet  0.580928  0.816493
# 4                                      Random forest  0.824975  0.951396
# 5                                      l2_poly_3_deg  0.728782  0.913270
# 6    Logistic Regression L1 wielksza ilosc features   0.664761  0.858629
# ...

# %%
rf_model = RandomForestClassifier(random_state=42)

# Fit the model on the training data
rf_model.fit(X_train_standardized, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
calculate_metrics(rf_model, 'Random forest  wieksza ilosc features', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      3000
#            1       0.92      0.90      0.91      1500
#
#     accuracy                           0.94      4500
#    macro avg       0.94      0.93      0.93      4500
# weighted avg       0.94      0.94      0.94      4500
#                                                Model  F1_score       AUC
# 0                                Logistic Regression  0.580928  0.816493
# 1                             Logistic Regression L1  0.580928  0.816493
# 2                             Logistic Regression L2  0.580928  0.816493
# 3                     Logistic Regression ElasticNet  0.580928  0.816493
# 4                                      Random forest  0.824975  0.951396
# 5                                      l2_poly_3_deg  0.728782  0.913270
# 6    Logistic Regression L1 wielksza ilosc features   0.664761  0.858629
# ...

# %%
poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train_standardized)
X_test_poly = poly.transform(X_test_standardized)

# %%
model_lr_l2_3deg = LogisticRegression(penalty='l2', solver='lbfgs', C=0.01, random_state=42)
model_lr_l2_3deg.fit(X_train_poly, y_train)
# Out:
# LogisticRegression(C=0.01, random_state=42)

# %%
calculate_metrics(model_lr_l2_3deg, 'l2_poly_3_deg wieksza ilosc features', X_test_poly, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      3000
#            1       0.84      0.81      0.82      1500
#
#     accuracy                           0.89      4500
#    macro avg       0.87      0.87      0.87      4500
# weighted avg       0.88      0.89      0.89      4500
#                                                 Model  F1_score       AUC
# 0                                 Logistic Regression  0.580928  0.816493
# 1                              Logistic Regression L1  0.580928  0.816493
# 2                              Logistic Regression L2  0.580928  0.816493
# 3                      Logistic Regression ElasticNet  0.580928  0.816493
# 4                                       Random forest  0.824975  0.951396
# 5                                       l2_poly_3_deg  0.728782  0.913270
# 6     Logistic Regression L1 wielksza ilosc features   0.664761  0.858629
# ...

# %% [markdown]
# ## F1 Score na zbiorach treningowych i testowych wazona

# %%
# Store F1 scores in a dictionary
f1_scores = {}
models_list = {
    'Logistic Regression L1': model_lr_l1,
    'Logistic Regression L2': model_lr_l2,
    'Logistic Regression ElasticNet': model_lr_l1_l2,  # Assuming model_lr_l1_l2 is ElasticNet
    'Random Forest': rf_model,
    'Logistic Regression Poly Deg 3': model_lr_l2_3deg
}
# Calculate and store F1 scores for each model
for model_name, model in models_list.items():
    # Handle different feature sets based on the model
    if model_name == 'Logistic Regression Poly Deg 3':
        # Use polynomial features for degree 3 model
        f1_train = f1_score(y_train, model.predict(X_train_poly), average='weighted')
        f1_test = f1_score(y_test, model.predict(X_test_poly), average='weighted')
    else:
        # Use standardized features for other models
        f1_train = f1_score(y_train, model.predict(X_train_standardized), average='weighted')
        f1_test = f1_score(y_test, model.predict(X_test_standardized), average='weighted')
    
    # Store the scores
    f1_scores[model_name] = {'F1_Train': f1_train, 'F1_Test': f1_test}

# Print the results in a formatted way
print("F1 Scores for Training and Test Sets wazona:")
print("-" * 50)
for model_name, scores in f1_scores.items():
    print(f"{model_name}:")
    print(f"  F1 Score (Train): {scores['F1_Train']:.4f}")
    print(f"  F1 Score (Test): {scores['F1_Test']:.4f}")
    print("-" * 50)
# Out:
# F1 Scores for Training and Test Sets wazona:
# --------------------------------------------------
# Logistic Regression L1:
#   F1 Score (Train): 0.7802
#   F1 Score (Test): 0.7874
# --------------------------------------------------
# Logistic Regression L2:
#   F1 Score (Train): 0.7801
#   F1 Score (Test): 0.7872
# --------------------------------------------------
# Logistic Regression ElasticNet:
#   F1 Score (Train): 0.7801
#   F1 Score (Test): 0.7872
# --------------------------------------------------
# Random Forest:
#   F1 Score (Train): 1.0000
#   F1 Score (Test): 0.9416
# --------------------------------------------------
# Logistic Regression Poly Deg 3:
#   F1 Score (Train): 0.8939
#   F1 Score (Test): 0.8851
# --------------------------------------------------

# %% [markdown]
# ## F1 Score na zbiorach treningowych i testowych class = 1

# %%
# Define the models and their names
# Store F1 scores in a dictionary
f1_scores = {}

# Calculate and store F1 scores for each model
for model_name, model in models_list.items():
    # Handle different feature sets based on the model
    if model_name == 'Logistic Regression Poly Deg 3':
        # Use polynomial features for degree 3 model
        f1_train = f1_score(y_train, model.predict(X_train_poly))
        f1_test = f1_score(y_test, model.predict(X_test_poly))
    else:
        # Use standardized features for other models
        f1_train = f1_score(y_train, model.predict(X_train_standardized))
        f1_test = f1_score(y_test, model.predict(X_test_standardized))
    
    # Store the scores
    f1_scores[model_name] = {'F1_Train': f1_train, 'F1_Test': f1_test}

# Print the results in a formatted way
print("F1 Scores for Training and Test Sets Class 1:")
print("-" * 50)
for model_name, scores in f1_scores.items():
    print(f"{model_name}:")
    print(f"  F1 Score (Train): {scores['F1_Train']:.4f}")
    print(f"  F1 Score (Test): {scores['F1_Test']:.4f}")
    print("-" * 50)
# Out:
# F1 Scores for Training and Test Sets Class 1:
# --------------------------------------------------
# Logistic Regression L1:
#   F1 Score (Train): 0.6498
#   F1 Score (Test): 0.6648
# --------------------------------------------------
# Logistic Regression L2:
#   F1 Score (Train): 0.6494
#   F1 Score (Test): 0.6643
# --------------------------------------------------
# Logistic Regression ElasticNet:
#   F1 Score (Train): 0.6494
#   F1 Score (Test): 0.6643
# --------------------------------------------------
# Random Forest:
#   F1 Score (Train): 1.0000
#   F1 Score (Test): 0.9114
# --------------------------------------------------
# Logistic Regression Poly Deg 3:
#   F1 Score (Train): 0.8376
#   F1 Score (Test): 0.8247
# --------------------------------------------------

# %% [markdown]
# # Trening na wiekszej ilosci features z uzyciem PCA

# %%
from sklearn.decomposition import PCA
# PCA z progiem 80%
pca_80 = PCA(n_components=0.80)
X_train_pca_80 = pca_80.fit_transform(X_train_standardized)
X_test_pca_80 = pca_80.transform(X_test_standardized)
print(f"PCA 80%: z {X_train_standardized.shape[1]} do {X_train_pca_80.shape[1]} cech")

# PCA z progiem 98%
pca_98 = PCA(n_components=0.98) 
X_train_pca_98 = pca_98.fit_transform(X_train_standardized)
X_test_pca_98 = pca_98.transform(X_test_standardized)
print(f"PCA 98%: z {X_train_standardized.shape[1]} do {X_train_pca_98.shape[1]} cech")
# Out:
# PCA 80%: z 8 do 7 cech
# PCA 98%: z 8 do 8 cech

# %%
# Model LR z PCA 80%
model_lr_pca80 = LogisticRegression()
model_lr_pca80.fit(X_train_pca_80, y_train)
print(f"Dokładność  LR (PCA 80%): {model_lr_pca80.score(X_test_pca_80, y_test):.4f}")
# Out:
# Dokładność  LR (PCA 80%): 0.7902

# %%
# Model LR z PCA 98%
model_lr_pca98 = LogisticRegression()
model_lr_pca98.fit(X_train_pca_98, y_train)
print(f"Dokładność LR (PCA 98%): {model_lr_pca98.score(X_test_pca_98, y_test):.4f}")
# Out:
# Dokładność LR (PCA 98%): 0.7913

# %%
# Model RF z PCA 80%
model_rf_pca80 = RandomForestClassifier(random_state=42)
model_rf_pca80.fit(X_train_pca_80, y_train)
print(f"Dokładność RF (PCA 80%): {model_rf_pca80.score(X_test_pca_80, y_test):.4f}")
# Out:
# Dokładność RF (PCA 80%): 0.8353

# %%
# Model LR z PCA 98%
model_rf_pca98 = RandomForestClassifier(random_state=42)
model_rf_pca98.fit(X_train_pca_98, y_train)
print(f"Dokładność RF (PCA 98%): {model_rf_pca98.score(X_test_pca_98, y_test):.4f}")
# Out:
# Dokładność RF (PCA 98%): 0.8849

# %%
print(f"Dokładność LF bez PCA: {model_lr.score(X_test_standardized, y_test):.4f}")
# Out:
# Dokładność LF bez PCA: 0.7913

# %%
print(f"Dokładność RF bez PCA: {rf_model.score(X_test_standardized, y_test):.4f}")
# Out:
# Dokładność RF bez PCA: 0.9418

# %% [markdown]
# # Podsumowanie

# %% [markdown]
# PCA nie ma wplywu na wyniki LF (z nia i bez niej dokladnosc jest taka sama)

# %% [markdown]
# PCA ma negatywny wplyw na wyniki RF (z nia i bez niej dokladnosc jest taka sama)
